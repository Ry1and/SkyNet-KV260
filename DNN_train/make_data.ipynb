# %%
import json
import os
from os.path import join
import glob
import xml.etree.ElementTree as ET
import pickle
import numpy as np
import PIL.Image as Image
import matplotlib.pyplot as plt
import random
# %matplotlib inline

# %%
#to dji_training
dataset_path = '../data_training/'
classes_name = []
classes_tags = []

# %%
for path in glob.glob(os.path.join(dataset_path, '*')):
    classes_name.append(path.replace(dataset_path,''))
    class_tag = []
    for gt_file in glob.glob(os.path.join(path, '*.xml')):
        class_tag_pair = []
        gt_img = gt_file.replace('.xml','.jpg')
        tree = ET.ElementTree(file=gt_file)
        b=np.zeros(4,dtype=float)
        for elem in tree.iter():
            if(elem.tag=='xmin'):
                b[0]=float(elem.text)
            if(elem.tag=='xmax'):
                b[1]=float(elem.text)
            if(elem.tag=='ymin'):
                b[2]=float(elem.text)
            if(elem.tag=='ymax'):
                b[3]=float(elem.text)
        if b[2]!= 0  and b[3]!= 0:
            img = Image.open(gt_img).convert('RGB')
            size = img.size
            bs = [(b[1]-b[0])*1./size[0],\
                  (b[3]-b[2])*1./size[1],\
                  (b[1]+b[0])*0.5/size[0],\
                 (b[2]+b[3])*0.5/size[1]]
            class_tag_pair.append(gt_img)
            class_tag_pair.append(bs)
            class_tag.append(class_tag_pair)
            #print(class_tag_pair)
    classes_tags.append(class_tag)
    print(path)
# Out:
# ../data_training\boat1
# ../data_training\boat2
# ../data_training\boat3
# ../data_training\boat4
# ../data_training\boat5
# ../data_training\boat6
# ../data_training\boat7
# ../data_training\building1
# ../data_training\building2
# ../data_training\building3
# ../data_training\car1
# ../data_training\car10
# ../data_training\car11
# ../data_training\car12
# ../data_training\car13
# ../data_training\car14
# ../data_training\car15
# ../data_training\car16
# ../data_training\car17
# ../data_training\car18
# ../data_training\car19
# ../data_training\car2
# ../data_training\car20
# ../data_training\car21
# ../data_training\car3
# ../data_training\car4
# ../data_training\car5
# ../data_training\car6
# ../data_training\car8
# ../data_training\car9
# ../data_training\drone1
# ../data_training\drone2
# ../data_training\drone3
# ../data_training\group2
# ../data_training\group3
# ../data_training\horseride1
# ../data_training\paraglider1
# ../data_training\person1
# ../data_training\person10
# ../data_training\person11
# ../data_training\person12
# ../data_training\person13
# ../data_training\person14
# ../data_training\person15
# ../data_training\person16
# ../data_training\person17
# ../data_training\person18
# ../data_training\person19
# ../data_training\person2
# ../data_training\person20
# ../data_training\person21
# ../data_training\person22
# ../data_training\person23
# ../data_training\person24
# ../data_training\person25
# ../data_training\person3
# ../data_training\person4
# ../data_training\person5
# ../data_training\person6
# ../data_training\person7
# ../data_training\person8
# ../data_training\person9
# ../data_training\riding1
# ../data_training\riding10
# ../data_training\riding11
# ../data_training\riding12
# ../data_training\riding13
# ../data_training\riding14
# ../data_training\riding15
# ../data_training\riding2
# ../data_training\riding3
# ../data_training\riding4
# ../data_training\riding5
# ../data_training\riding6
# ../data_training\riding7
# ../data_training\riding8
# ../data_training\riding9
# ../data_training\truck1
# ../data_training\truck2
# ../data_training\wakeboard1
# ../data_training\wakeboard2
# ../data_training\wakeboard3
# ../data_training\whale1

# %%
with open('dji_2021.txt', 'w') as outfile:
    json.dump(classes_tags, outfile)

# %%
with open('dji_2021.txt', 'r') as outfile:
    data_loaded = json.load(outfile)

# %%
#to UAV123
dataset_path = '/home/leeyh/Downloads/UAV123/data_seq/UAV123/'
gts_path = '/home/leeyh/Downloads/UAV123/anno/UAV/'

# %%
classes_name = []
classes_tags = []
for path in glob.glob(os.path.join(gts_path, '*.txt')):
    classes_name.append(path.replace(gts_path,'').replace('.txt',''))
    
    gts = np.loadtxt(path,delimiter = ',')
    class_tag = []
    
    img_folder_path = os.path.join(dataset_path, path.replace(gts_path,'').replace('.txt',''))
    print img_folder_path
    for i in xrange(len(gts)):
        class_tag_pair = []
        gt_img = os.path.join(img_folder_path,'%06d.jpg'%(i+1))

        if os.path.exists(gt_img):
            if gts[i][2]!=0 and gts[i][3]!= 0 and np.isnan(gts[i][2]) ==False and  np.isnan(gts[i][3]) ==False:
                img = Image.open(gt_img).convert('RGB')
                size = img.size
                bs = [gts[i][2]/size[0],gts[i][3]/size[1],gts[i][0]/size[0],gts[i][1]/size[1]]
                class_tag_pair.append(gt_img)
                class_tag_pair.append(bs)
                class_tag.append(class_tag_pair)
    classes_tags.append(class_tag)
# Out:
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/person22
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/car1
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/car1_s
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/person10
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/car5
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/person11
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/building4
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/building2
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/person8
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/uav5
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/car8
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/uav3
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/group1
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/car15
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/wakeboard3
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/car17
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/person1_s
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/person21
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/uav2
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/car12
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/group2
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/boat3
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/car3_s
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/person9
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/uav4
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/person18
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/boat5
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/uav8
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/person1
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/wakeboard2
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/person2_s
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/boat4
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/car2
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/truck3
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/wakeboard4
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/car11
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/person20
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/group3
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/car2_s
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/wakeboard10
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/boat8
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/truck2
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/car10
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/bird1
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/boat9
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/bike3
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/person23
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/car18
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/person19
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/uav6
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/boat7
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/person13
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/boat1
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/person4
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/wakeboard9
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/wakeboard7
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/person17
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/person3_s
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/building1
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/bike2
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/car9
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/boat6
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/building5
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/car4_s
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/car3
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/car6
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/wakeboard1
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/person3
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/car16
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/building3
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/truck1
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/bike1
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/car13
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/person2
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/boat2
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/wakeboard5
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/car7
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/person5
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/person16
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/car4
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/uav7
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/person15
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/person6
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/truck4
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/car14
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/wakeboard6
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/uav1
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/person14
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/wakeboard8
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/person7
# /home/leeyh/Downloads/UAV123/data_seq/UAV123/person12

# %%
for seq in classes_tags:
    for fr in seq:
        fr[1][2] = fr[1][2] + fr[1][0]/2
        fr[1][3] = fr[1][3] + fr[1][1]/2

# %%
with open('uav.txt', 'w') as outfile:
    json.dump(classes_tags, outfile)

# %%
with open('test.txt', 'r') as outfile:
    data_loaded = json.load(outfile)

# %%
a = random.choice(data_loaded)
b = random.choice(a)

# %%
random.randint(-1,1)
# Out:
# -1

# %%
data_loaded[0][1]
# Out:
# ['/home/leeyh/Downloads/dji_test/sample/993.jpg',
#  [0.034375, 0.08055555555555556, 0.4875, 0.5208333333333334]]

# %%
ind = 0

# %%
len(data_loaded[ind])-1
# Out:
# 995

# %%
a = data_loaded[ind][5]

# %%
img = Image.open(a[0])

# %%
plt.imshow(img)

# %%
w = a[1][0]*img.size[0]
h = a[1][1]*img.size[1]
x = a[1][2]*img.size[0]
y = a[1][3]*img.size[1]
minx = x -w/2
miny = y - h/2
maxx = x+w/2
maxy = y+h/2

# %%
img.crop((minx,miny,maxx,maxy))
# Out:
# <PIL.Image.Image image mode=RGB size=19x52 at 0x3FFF95103D90>

# %%
#to dji_test
dataset_path = '../data_test/'
classes_name = []
classes_tags = []

# %%
for path in glob.glob(os.path.join(dataset_path, '*')):
    if path == '/home/leeyh/Downloads/dji_test/sample':
        classes_name.append(path.replace(dataset_path,''))
        class_tag = []
        for gt_file in glob.glob(os.path.join(path, '*.xml')):
            class_tag_pair = []
            gt_img = gt_file.replace('.xml','.jpg')
            tree = ET.ElementTree(file=gt_file)
            b=np.zeros(4,dtype=float)
            for elem in tree.iter():
                if(elem.tag=='xmin'):
                    b[0]=float(elem.text)
                if(elem.tag=='xmax'):
                    b[1]=float(elem.text)
                if(elem.tag=='ymin'):
                    b[2]=float(elem.text)
                if(elem.tag=='ymax'):
                    b[3]=float(elem.text)
            if b[2]!= 0  and b[3]!= 0:
                img = Image.open(gt_img).convert('RGB')
                size = img.size
                bs = [(b[1]-b[0])*1./size[0],\
                      (b[3]-b[2])*1./size[1],\
                      (b[1]+b[0])*0.5/size[0],\
                     (b[2]+b[3])*0.5/size[1]]
                class_tag_pair.append(gt_img)
                class_tag_pair.append(bs)
                class_tag.append(class_tag_pair)
        classes_tags.append(class_tag)
    print path
# Out:
# /home/leeyh/Downloads/dji_test/sample
# /home/leeyh/Downloads/dji_test/sampleBounded

# %%
classes_tags[0][0]
# Out:
# ['/home/leeyh/Downloads/dji_test/sample/932.jpg',
#  [0.032812500000000001,
#   0.083333333333333329,
#   0.48984375000000002,
#   0.50555555555555554]]

# %%
with open('test.txt', 'w') as outfile:
    json.dump(classes_tags, outfile)
